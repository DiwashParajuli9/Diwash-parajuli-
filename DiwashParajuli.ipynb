# %% [markdown]
# # Environment Setup

# %%
pip install numpy pandas matplotlib seaborn jupyter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Data Structures

# %%
# List practice
my_list = ["Diwash", "Parajuli", 25, "Engineering", True]
my_list.append("Python")
my_list.insert(2, "Biratnagar")
my_list.remove(True)
my_list[0] = "Mr. Diwash"
print(my_list)
print(my_list[1:4])

# Tuple practice
my_tuple = ("Coke", "Juice", "cat", "Diwash", "Parajuli")
print(my_tuple)
print(my_tuple[3])
for item in my_tuple:
    print(item)

# Dictionary practice
my_dict = {
    "first_name": "Diwash",
    "last_name": "Parajuli",
    "age": 25,
    "occupation": "Software Developer"
}
print(my_dict)
print(my_dict["occupation"])
my_dict["city"] = "Biratnagar"
my_dict["age"] = 20
print(my_dict)
del my_dict["occupation"]
print(my_dict)
print(my_dict.keys())
print(my_dict.values())

# Set practice
my_set = {"Diwash", "Parajuli", "Student", "Engeneering", "Python"}
print(my_set)
my_set.add("AI")
my_set.remove("Parajuli")
print(my_set)
another_set = {"Java", "Developer", "Diwash"}
union_set = my_set.union(another_set)
print(union_set)
intersection_set = my_set.intersection(another_set)
print(intersection_set)
# Out:
# ['Mr. Diwash', 'Parajuli', 'Biratnagar', 25, 'Engineering', 'Python']
# ['Parajuli', 'Biratnagar', 25]
# ('Coke', 'Juice', 'cat', 'Diwash', 'Parajuli')
# Diwash
# Coke
# Juice
# cat
# Diwash
# Parajuli
# {'first_name': 'Diwash', 'last_name': 'Parajuli', 'age': 25, 'occupation': 'Software Developer'}
# Software Developer
# {'first_name': 'Diwash', 'last_name': 'Parajuli', 'age': 20, 'occupation': 'Software Developer', 'city': 'Biratnagar'}
# {'first_name': 'Diwash', 'last_name': 'Parajuli', 'age': 20, 'city': 'Biratnagar'}
# dict_keys(['first_name', 'last_name', 'age', 'city'])
# dict_values(['Diwash', 'Parajuli', 20, 'Biratnagar'])
# {'Python', 'Diwash', 'Student', 'Parajuli', 'Engeneering'}
# {'Python', 'Diwash', 'Student', 'AI', 'Engeneering'}
# {'Python', 'Developer', 'Java', 'Diwash', 'Student', 'AI', 'Engeneering'}
# {'Diwash'}

# %% [markdown]
# # OOP Concepts

# %%
# Define a class named Person
class Person:
    # The __init__ method is the constructor for the class.
    # It's called when a new object (instance) of the class is created.
    def __init__(self, first_name, last_name, age):
        # Attributes (data) of the Person object
        self.first_name = first_name
        self.last_name = last_name
        self.age = age

    # Method to get the full name of the person
    def get_full_name(self):
        return f"{self.first_name} {self.last_name}"

    # Method to display information about the person
    def display_info(self):
        print(f"Name: {self.get_full_name()}")
        print(f"Age: {self.age}")

# Create objects (instances) of the Person class
# Diwash's object
diwash = Person("Diwash", "Parajuli", 20)

# Parajuli's object (assuming a different person with the same last name or just another example)
another_parajuli = Person("Another", "Parajuli", 20)

# Access attributes and call methods using the objects
print("--- Diwash's Information ---")
diwash.display_info()
print(f"Diwash's full name: {diwash.get_full_name()}")

print("\n--- Another Parajuli's Information ---")
another_parajuli.display_info()
print(f"Another Parajuli's full name: {another_parajuli.get_full_name()}")

# You can also change attributes after creation
diwash.age = 20
print(f"\nDiwash's updated age: {diwash.age}")
# Out:
# --- Diwash's Information ---
# Name: Diwash Parajuli
# Age: 20
# Diwash's full name: Diwash Parajuli
#
# --- Another Parajuli's Information ---
# Name: Another Parajuli
# Age: 20
# Another Parajuli's full name: Another Parajuli
#
# Diwash's updated age: 20

# %% [markdown]
# # Asynchrounous Programming

# %%
import asyncio

# I'm defining a class here called 'Person'.
# This is like a blueprint for creating person objects.
class Person:
    # This is my constructor, '__init__'.
    # It runs every time I create a new 'Person' object.
    def __init__(self, first_name, last_name, age):
        self.first_name = first_name
        self.last_name = last_name
        self.age = age

    # This is a method to get the full name.
    # It just combines the first and last name for me.
    def get_full_name(self):
        return f"{self.first_name} {self.last_name}"

    async def perform_async_task(self):
        print(f"{self.get_full_name()} is starting an asynchronous task...")
        # I'm using 'await asyncio.sleep(2)' here.
   
        await asyncio.sleep(2)
        print(f"{self.get_full_name()} has finished the asynchronous task.")
        return f"{self.get_full_name()}'s task completed!"

    # This is just a simple method to print out the person's information.
    def display_info(self):
        print(f"Name: {self.get_full_name()}")
        print(f"Age: {self.age}")

# This is my main asynchronous function where I'll run everything.
async def main():
    # I'm creating two 'Person' objects here.
    # One for Diwash and one for another person named parajuli.
    diwash = Person("Diwash", "parajuli", 20)
    another_parajuli = Person("Another", "Parajuli", 25)

    # I'm just printing out Diwash's information to see if it works.
    print("--- Diwash's Information ---")
    diwash.display_info()
    print(f"Diwash's full name: {diwash.get_full_name()}")

    # And now for the other Parajuli person.
    print("\n--- Another Parajuli's Information ---")
    another_parajuli.display_info()
    print(f"Another parajuli's full name: {another_parajuli.get_full_name()}")

    # I'm updating Diwash's age here.
    diwash.age = 21
    print(f"\nDiwash's updated age: {diwash.age}")

    print("\n--- Demonstrating Asynchronous Tasks ---")
    # This is the exciting part! I'm scheduling both diwash's and Parajuli's async tasks.
    # They're going to run at the same time, or at least appear to.
    task1 = diwash.perform_async_task()
    task2 = another_parajuli.perform_async_task()

    # I'm using 'await asyncio.gather(task1, task2)' to wait for both tasks to complete.
    # This ensures my program doesn't move on until both simulated long-running tasks are done.
    results = await asyncio.gather(task1, task2)
    print("\nAll asynchronous tasks completed. Results:")
    for res in results:
        print(res)


await main()
# Out:
# --- Diwash's Information ---
# Name: Diwash parajuli
# Age: 20
# Diwash's full name: Diwash parajuli
#
# --- Another Parajuli's Information ---
# Name: Another Parajuli
# Age: 25
# Another parajuli's full name: Another Parajuli
#
# Diwash's updated age: 21
#
# --- Demonstrating Asynchronous Tasks ---
# Diwash parajuli is starting an asynchronous task...
# Another Parajuli is starting an asynchronous task...
# Diwash parajuli has finished the asynchronous task.
# Another Parajuli has finished the asynchronous task.
#
# All asynchronous tasks completed. Results:
# Diwash parajuli's task completed!
# Another Parajuli's task completed!

# %% [markdown]
# # Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- NumPy: Arrays and Operations ---

# Creating a NumPy array from a list of integers.
arr = np.array([1, 2, 3, 4])
print("Original NumPy array:", arr)

# Performing an element-wise operation, multiplying the array by a scalar.
scaled_arr = arr * 2
print("Scaled NumPy array (multiplied by 2):", scaled_arr)

# --- Pandas: DataFrames ---

# Defining a dictionary to structure the data.
data_dict = {
    "Name": ["Diwash", "Parajuli", "John", "Doe"],
    "Score": [90, 85, 88, 94],
    "City": ["Itahari", "Biratnagar", "Kathmandu", "Urlabari"]
}

# Constructing a Pandas DataFrame from the prepared dictionary.
df = pd.DataFrame(data_dict)
print("\nPandas DataFrame:\n", df)

# Selecting a specific column, 'Name', from the DataFrame.
names = df["Name"]
print("\nNames column from DataFrame:\n", names)

# --- Matplotlib: Basic Plotting ---

# Preparing simple numerical data for visualization.
x_values = [1, 2, 3, 4, 5]
y_values = [12, 17, 4, 24, 14]

# Creating a new figure for the plot and defining its size.
plt.figure(figsize=(7, 5))
# Generating a line plot using the x and y values.
plt.plot(x_values, y_values)
# Setting the title of the plot for clarity.
plt.title("Simple Line Plot Example")
# Labeling the x-axis.
plt.xlabel("X-axis Label")
# Labeling the y-axis.
plt.ylabel("Y-axis Label")
# Adding a grid to the plot for enhanced readability.
plt.grid(True, linestyle='--', alpha=0.7)
# Displaying the generated plot.
plt.show()
# Out:
# Original NumPy array: [1 2 3 4]
# Scaled NumPy array (multiplied by 2): [2 4 6 8]
#
# Pandas DataFrame:
#         Name  Score        City
# 0    Diwash     90     Itahari
# 1  Parajuli     85  Biratnagar
# 2      John     88   Kathmandu
# 3       Doe     94    Urlabari
#
# Names column from DataFrame:
#  0      Diwash
# 1    Parajuli
# 2        John
# 3         Doe
# Name: Name, dtype: object
